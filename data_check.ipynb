# %%
import joblib
import polars as pl
import re
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import sys
sys.path.append(r"/Workspace/9900-f18a-cake/working_branch/src")


CSV_PATH = "/Volumes/cb_prod/comp9300-9900-f18a-cake/9900-f18a-cake/data/mvalue_outputs_masked/MValue_concat.csv"
# CSV_PATH = "/Volumes/cb_prod/comp9300-9900-f18a-cake/9900-f18a-cake/data/mvalue_outputs_masked_subset_leukaemia_subsampled/MValue_polaris_pivot_0.csv"
# CSV_PATH = "/Volumes/cb_prod/comp9300-9900-f18b-cake/9900-f18b-cake/data/mvalue_outputs_masked/MValue_concat.csv"
JOBLIB_PATH = "/Workspace/9900-f18a-cake/working_branch/data/freeze0525/diseaseTree_mapped.joblib"
OUTPUT_PATH = "/Workspace/9900-f18a-cake/working_branch/data/freeze0525/biosample_alignment.csv"

ID_PATTERN = re.compile(r".*_T_.*_M$")  # 2J0D2U4J_T_XJAFP6HU_M

try:
    df_csv = pl.read_csv(CSV_PATH, columns=["biosample_id"], ignore_errors=True)
except Exception:
    df_csv = pl.read_csv(CSV_PATH, ignore_errors=True)
    if "biosample_id" not in df_csv.columns:
        for c in df_csv.columns:
            if c.lower() == "biosample_id":
                df_csv = df_csv.rename({c: "biosample_id"})
                break

csv_ids = [str(x).strip() for x in df_csv["biosample_id"].to_list() if x and str(x).strip()]
print(f"read csv done {len(csv_ids)} samples total")
print(csv_ids[:10])

def deep_scan_ids(obj, ids: set, _depth=0, _maxdepth=8):
    if obj is None or _depth > _maxdepth:
        return
    if isinstance(obj, str):
        if ID_PATTERN.match(obj):
            ids.add(obj)
        return
    if isinstance(obj, (list, tuple, set)):
        for it in obj:
            deep_scan_ids(it, ids, _depth + 1)
        return
    if isinstance(obj, dict):
        for k, v in obj.items():
            if isinstance(k, str) and ID_PATTERN.match(k):
                ids.add(k)
            deep_scan_ids(v, ids, _depth + 1)
        return
    if hasattr(obj, "__dict__"):
        deep_scan_ids(vars(obj), ids, _depth + 1)

obj = joblib.load(JOBLIB_PATH)
joblib_ids = set()
deep_scan_ids(obj, joblib_ids)
joblib_ids = sorted(joblib_ids)

from pprint import pprint

print(type(obj))
pprint(obj)

print(f"read Joblib done {len(joblib_ids)} samples total")
print(joblib_ids[:10])


csv_set = set(csv_ids)
joblib_set = set(joblib_ids)

intersection = csv_set & joblib_set
csv_only = csv_set - joblib_set
joblib_only = joblib_set - csv_set

print(f"🔹 CSV count: {len(csv_set)}")
print(f"🔹 Joblib count: {len(joblib_set)}")
print(f"🔹 joint count: {len(intersection)}")
print(f"🔹 CSV only: {len(csv_only)}")
print(f"🔹 Joblib only: {len(joblib_only)}")



plt.figure(figsize=(6,5))
plt.bar(["CSV only", "Joblib only", "Align"], 
        [len(csv_only), len(joblib_only), len(intersection)],
        color=["#66c2a5", "#fc8d62", "#8da0cb"])
plt.ylabel("Sample cnt")
plt.title("Biosample ID joint")
for i, v in enumerate([len(csv_only), len(joblib_only), len(intersection)]):
    plt.text(i, v + 2, str(v), ha="center", fontweight="bold")
plt.show()

alignment_df = pd.DataFrame({
    "biosample_id_csv": list(csv_set),
    "in_joblib": [x in joblib_set for x in csv_set]
})

Path(OUTPUT_PATH).parent.mkdir(parents=True, exist_ok=True)
alignment_df.to_csv(OUTPUT_PATH, index=False)
print(f"Align output: {OUTPUT_PATH}")
alignment_df.head(10)
# Out:
# read csv done 2470 samples total
# ['1EBDUQQD_T_8W1S2CJG_M', '18BHF2X3_T_18BB27NK_M', '1JNRPR2G_T_NE5MCS8F_M', 'TM4YM7P7_T_C65CQPHJ_M', '2DU8AC0K_T_1U2QNMSK_M', '1BKMVG7L_T_2KQHASWV_M', '9Q7TE60T_T_2PSBEHP9_M', 'VTG9EGAQ_T_2H0TTWDA_M', '1VKEQRGT_T_DS4BWH8J_M', 'KBAWA9H2_T_9JLNF2X5_M']
# <class 'mch.core.disease_tree.DiseaseTree'>
# DiseaseTree(name='ZERO2',
#             children=[DiseaseTree(name='Neuroblastoma',
#                                   children=[DiseaseTree(name='Olfactory '
#                                                              'neuroblastoma',
#                                                         children=[],
#                                                         samples=['WKKCTLNZ_T_2DQ5W5GT_M',
#                                                                  'WKKCTLNZ_T_15TGKHYY_M'],
#                                                         training_samples=['WKKCTLNZ_T_2DQ5W5GT_M',
#                                                                           'WKKCTLNZ_T_15TGKHYY_M'],
#                                                         validation_samples=[],
#                                                         selected_features=[])],
#                                   samples=['2J0D2U4J_T_XJAFP6HU_M',
#                                            '1Y5U23JX_T_2BJWTAD0_M',
#                                            'LLV8BE5A_T_49HWBVUM_M',
#                                            '28UATA2X_T_2846CY4M_M',
#                                            '2TY83VAJ_T_26ZX1KHP_M',
#                                            '1H47E0HB_T_1UQYH262_M',
#                                            '2UTJB08M_T_R0DDKFK3_M',
#                                            '1JNRPR2G_T_NE5MCS8F_M',
#                                            '2B1KPTJ3_T_2QQYFZHC_M',
#                                            '2GBWAUW0_T_2CW5VY1P_M',
#                                            '211JUCLW_T_CV2PEL1D_M',
#                                            '2DD8RVP8_T_XHLPBARC_M',
#                                            '1WJVKTEE_T_JB90WYFQ_M',
#                                            '9SFT5VT0_T_XBLWEF3K_M',
#                                            '20V9SZ3Y_T_10FZ8FC9_M',
#                                            '14TMLV7X_T_LVNKHGVE_M',
#                                            '2LNTMQ22_T_26C28QNQ_M',
#                                            '26QH40NW_T_2PRR89YC_M',
#                                            '259SC0ER_T_1B7EEYQQ_M',
#                                            '259SC0ER_T_1W8Q76ZV_M',
#                                            '1ZMN1AHD_T_6YMK9CY3_M',
#                                            '2P0LAC3K_T_1ZR3X8JX_M',
#                                            '1Z401KC5_T_L5AKQWLD_M',
#                                            '1HCPSQCN_T_1Q91BXJR_M',
#                                            'CL30TMZY_T_R4GJ0PFA_M',
#                                            '32NUWK0T_T_2467UQ2C_M',
#                                            '58FT71MT_T_2RVANZZY_M',
#                                            '28HQQJ3K_T_18CH055Z_M',
#                                            '404DHL8V_T_KYUMMXFY_M',
#                                            '2BTX94BF_T_2ABTZRNK_M',
#                                            '1EL1JBNA_T_1K246FD3_M',
#                                            'GJGVFS0F_T_1ZPQY795_M',
#                                            '2JHYNCU2_T_3145C3WC_M',
#                                            '1BH0ZUW3_T_28VLPVQ3_M',
#                                            '4CUZYSZB_T_2NR1GD4U_M',
#                                            '2GXA5UDZ_T_HNQKQREH_M',
#                                            '2QVDZC03_T_2DSJRRRN_M',
#                                            'XNQGHN6D_T_1YWRXWGK_M',
#                                            'XNQGHN6D_T_271G3BAH_M',
#                                            'XTCJABJD_T_25ZR1A4B_M',
#                                            '2P0C5PZ7_T_1VVEY31Y_M',
#                                            '1CM2N5F3_T_6WUS9X8Y_M',
#                                            '16AFE0RY_T_16XF153Q_M',
#                                            '1154A61T_T_240EGBJN_M',
#                                            'LQTBGPJW_T_28B0NLRM_M',
#                                            '1WQ1G6GC_T_2S88HCTD_M',
#                                            '25DV81BS_T_1S777M7Y_M',
#                                            'NV63FNHJ_T_LP8A24CG_M',
#                                            '2Y5YACMD_T_NNW7P1LS_M',
#                                            '2Y5YACMD_T_31R9M6QR_M',
#                                            '2KUF3D3L_T_1AXFJYXS_M',
#                                            '2KUF3D3L_T_1XXBH0A8_M',
#                                            '1VXBP9GC_T_2JWSGVA4_M',
#                                            '2WEWUYKU_T_1Y7AXE3M_M',
#                                            '29PV7AFR_T_2BLE6M4E_M',
#                                            'EG5TY090_T_UUL19HXL_M',
#                                            '2GY09WZM_T_YFQ7AU5J_M',
#                                            '2F14HYG8_T_2UJXEZZE_M',
#                                            'GC9CYY0B_T_2RMPFGVL_M',
#                                            '2X2KQUJM_T_BMZ2AQQG_M',
#                                            'QA96N5VP_T_258Y2YX1_M',
#                                            '68S24AC3_T_28KPEA9V_M',
#                                            '21VX8G3P_T_PCZTVQRT_M',
#                                            'JB3ZH6KS_T_1WMTLZDD_M',
#                                            '23Y760LJ_T_2J0J64U5_M',
#                                            '2KWRLZX7_T_1BCHMQY1_M',
#                                            '20AAMEJG_T_25WTUUTZ_M',
#                                            '1N09Q4K3_T_2A3XTVHJ_M',
#                                            '1N09Q4K3_T_22AADBU0_M',
#                                            '11UWUZG9_T_2J5K19WW_M',
#                                            '2HYC4N57_T_273HC47R_M',
#                                            'QS12MY8C_T_1L09WYMN_M',
#                                            '1SHJ88W1_T_AQ9TJ4W9_M',
#                                            '32EEXL0X_T_1CD4PX1X_M',
#                                            'CCFL2P1X_T_1YL1EQT2_M',
#                                            '1058BL97_T_1W2L50GD_M',
#                                            '18XF3EWD_T_2GCRYVSC_M',
#                                            '1J1286J9_T_2VUR1EUD_M',
#                                            '2RN12Q9W_T_S9Q6DZRP_M',
#                                            '28S29JSE_T_1YJVZC3P_M',
#                                            '1LERGWPS_T_1PG4YZLU_M',
#                                            '2H6SVADE_T_30LLKT3P_M',
#                                            '1RLFRAJC_T_16ZTLW6Z_M',
#                                            '27Q8GEVE_T_1Z5VNC9D_M',
#                                            'DXMFVA0P_T_2N7DFDDS_M',
#                                            'AL9HKC46_T_2UMEZXWP_M',
#                                            '1LWMLSZ1_T_TA0LZK7X_M',
#                                            '4D3PQXYW_T_158V0K3R_M',
#                                            '21ZTC3S8_T_14ENBPKZ_M',
#                                            '1HVB7MQE_T_14PFY6CD_M',
#                                            '27Z6MTZT_T_Q7VRBYHS_M',
#                                            '1Y5U23JX_T_MVWVAMPK_M',
#                                            '1Y5U23JX_T_TWVZ4283_M',
#                                            '1C7CRKRQ_T_1YP0JZ9M_M',
#                                            '20CUBC58_T_LGECNKJQ_M',
#                                            '12Y3706V_T_227JABDK_M',
#                                            '13FGQ1RK_T_31DX5T5P_M',
#                                            '1JE4X3CZ_T_5FN9UABW_M',
#                                            '5CV3CJEY_T_250QSX5R_M',
#                                            'NV63FNHJ_T_21FGKWBH_M',
#                                            '2SNETBLP_T_1JUYXNX7_M',
#                                            'DY7JLL1C_T_2K6SZ95U_M',
#                                            '1Y5U23JX_T_CX4VAEYF_M',
#                                            'L3P1BD91_T_4QL24TFM_M',
#                                            'E6DWEFY1_T_194SGHYH_M',
#                                            '2QXBEUWG_T_YMCA07ST_M',
#                                            '5ZB6LPJX_T_2H9HSH0C_M',
#                                            'J0PSXTD4_T_2DVBP6PS_M',
#                                            'V20LWAKK_T_L76Z4QRZ_M',
#                                            'VPXWP5NZ_T_32EEENGL_M',
#                                            '2GYT5RNM_T_1GR2RR9X_M',
#                                            '1XKJVYPQ_T_9MUZXBUX_M',
#                                            '1XKJVYPQ_T_DQ2R51DN_M',
#                                            'GJGVFS0F_T_1TEQPUDH_M',
#                                            '1TJLXS72_T_2ETE4SDP_M',
#                                            '2LMVH2Z0_T_272GVVME_M',
#                                            'BGP50MMX_T_1FR40LBS_M'],
#                                   training_samples=['23Y760LJ_T_2J0J64U5_M',
#                                                     '2KWRLZX7_T_1BCHMQY1_M',
#                                                     '1WJVKTEE_T_JB90WYFQ_M',
#                                                     'GJGVFS0F_T_1ZPQY795_M',
#                                                     '28HQQJ3K_T_18CH055Z_M',
#                                                     'CL30TMZY_T_R4GJ0PFA_M',
#                                                     '4D3PQXYW_T_158V0K3R_M',
#                                                     'DY7JLL1C_T_2K6SZ95U_M',
#                                                     'AL9HKC46_T_2UMEZXWP_M',
#                                                     '14TMLV7X_T_LVNKHGVE_M',
#                                                     'QS12MY8C_T_1L09WYMN_M',
#                                                     '1Z401KC5_T_L5AKQWLD_M',
#                                                     '1WQ1G6GC_T_2S88HCTD_M',
#                                                     'QA96N5VP_T_258Y2YX1_M',
#                                                     '1EL1JBNA_T_1K246FD3_M',
#                                                     '2RN12Q9W_T_S9Q6DZRP_M',
#                                                     '21VX8G3P_T_PCZTVQRT_M',
#                                                     '2GBWAUW0_T_2CW5VY1P_M',
#                                                     '1BH0ZUW3_T_28VLPVQ3_M',
#                                                     '68S24AC3_T_28KPEA9V_M',
#                                                     '32NUWK0T_T_2467UQ2C_M',
#                                                     '1N09Q4K3_T_22AADBU0_M',
#                                                     '404DHL8V_T_KYUMMXFY_M',
#                                                     '2WEWUYKU_T_1Y7AXE3M_M',
#                                                     '1TJLXS72_T_2ETE4SDP_M',
#                                                     '2KUF3D3L_T_1AXFJYXS_M',
#                                                     '1H47E0HB_T_1UQYH262_M',
#                                                     'JB3ZH6KS_T_1WMTLZDD_M',
#                                                     '1Y5U23JX_T_MVWVAMPK_M',
#                                                     'NV63FNHJ_T_LP8A24CG_M',
#                                                     '2GXA5UDZ_T_HNQKQREH_M',
#                                                     '2LNTMQ22_T_26C28QNQ_M',
#                                                     '4CUZYSZB_T_2NR1GD4U_M',
#                                                     '28S29JSE_T_1YJVZC3P_M',
#                                                     '1JNRPR2G_T_NE5MCS8F_M',
#                                                     '1CM2N5F3_T_6WUS9X8Y_M',
#                                                     '1XKJVYPQ_T_9MUZXBUX_M',
#                                                     'VPXWP5NZ_T_32EEENGL_M',
#                                                     '5CV3CJEY_T_250QSX5R_M',
#                                                     '2B1KPTJ3_T_2QQYFZHC_M',
#                                                     '9SFT5VT0_T_XBLWEF3K_M',
#                                                     '27Q8GEVE_T_1Z5VNC9D_M',
#                                                     '28UATA2X_T_2846CY4M_M',
#                                                     '26QH40NW_T_2PRR89YC_M',
#                                                     'XNQGHN6D_T_271G3BAH_M',
#                                                     '1N09Q4K3_T_2A3XTVHJ_M',
#                                                     'L3P1BD91_T_4QL24TFM_M',
#                                                     '2UTJB08M_T_R0DDKFK3_M',
#                                                     'V20LWAKK_T_L76Z4QRZ_M',
#                                                     '2SNETBLP_T_1JUYXNX7_M',
#                                                     '12Y3706V_T_227JABDK_M',
#                                                     '2KUF3D3L_T_1XXBH0A8_M',
#                                                     '2Y5YACMD_T_NNW7P1LS_M',
#                                                     'LQTBGPJW_T_28B0NLRM_M',
#                                                     'J0PSXTD4_T_2DVBP6PS_M',
#                                                     'GC9CYY0B_T_2RMPFGVL_M',
#                                                     'GJGVFS0F_T_1TEQPUDH_M',
#                                                     'CCFL2P1X_T_1YL1EQT2_M',
#                                                     '20CUBC58_T_LGECNKJQ_M',
#                                                     '2P0C5PZ7_T_1VVEY31Y_M',
#                                                     'EG5TY090_T_UUL19HXL_M',
#                                                     'DXMFVA0P_T_2N7DFDDS_M',
#                                                     '25DV81BS_T_1S777M7Y_M',
#                                                     '1RLFRAJC_T_16ZTLW6Z_M',
#                                                     'NV63FNHJ_T_21FGKWBH_M',
#                                                     '29PV7AFR_T_2BLE6M4E_M',
#                                                     '2HYC4N57_T_273HC47R_M',
#                                                     '2JHYNCU2_T_3145C3WC_M',
#                                                     '2GY09WZM_T_YFQ7AU5J_M',
#                                                     '2X2KQUJM_T_BMZ2AQQG_M',
#                                                     '1XKJVYPQ_T_DQ2R51DN_M',
#                                                     'XNQGHN6D_T_1YWRXWGK_M',
#                                                     '2BTX94BF_T_2ABTZRNK_M',
#                                                     'E6DWEFY1_T_194SGHYH_M',
#                                                     '1Y5U23JX_T_2BJWTAD0_M',
#                                                     '2P0LAC3K_T_1ZR3X8JX_M',
#                                                     'LLV8BE5A_T_49HWBVUM_M',
#                                                     '1HCPSQCN_T_1Q91BXJR_M',
#                                                     '1JE4X3CZ_T_5FN9UABW_M',
#                                                     '1C7CRKRQ_T_1YP0JZ9M_M',
#                                                     '2H6SVADE_T_30LLKT3P_M',
#                                                     '5ZB6LPJX_T_2H9HSH0C_M',
#                                                     '11UWUZG9_T_2J5K19WW_M',
#                                                     '1LERGWPS_T_1PG4YZLU_M',
#                                                     '1J1286J9_T_2VUR1EUD_M',
#                                                     'BGP50MMX_T_1FR40LBS_M',
#                                                     '1ZMN1AHD_T_6YMK9CY3_M',
#                                                     '2F14HYG8_T_2UJXEZZE_M',
#                                                     '20AAMEJG_T_25WTUUTZ_M',
#                                                     '20V9SZ3Y_T_10FZ8FC9_M',
#                                                     '1LWMLSZ1_T_TA0LZK7X_M',
#                                                     '2Y5YACMD_T_31R9M6QR_M',
#                                                     '13FGQ1RK_T_31DX5T5P_M'],
#                                   validation_samples=['58FT71MT_T_2RVANZZY_M',
#                                                       '1Y5U23JX_T_CX4VAEYF_M',
#                                                       '18XF3EWD_T_2GCRYVSC_M',
#                                                       '1VXBP9GC_T_2JWSGVA4_M',
#                                                       '16AFE0RY_T_16XF153Q_M',
#                                                       '27Z6MTZT_T_Q7VRBYHS_M',
#                                                       '1058BL97_T_1W2L50GD_M',
#                                                       '2LMVH2Z0_T_272GVVME_M',
#                                                       '2QXBEUWG_T_YMCA07ST_M',
#                                                       '1154A61T_T_240EGBJN_M',
#                                                       '2TY83VAJ_T_26ZX1KHP_M',
#                                                       '259SC0ER_T_1B7EEYQQ_M',
#                                                       '1HVB7MQE_T_14PFY6CD_M',
#                                                       '2QVDZC03_T_2DSJRRRN_M',
#                                                       '21ZTC3S8_T_14ENBPKZ_M',
#                                                       '259SC0ER_T_1W8Q76ZV_M',
#                                                       '2GYT5RNM_T_1GR2RR9X_M',
#                                                       '211JUCLW_T_CV2PEL1D_M',
#                                                       'XTCJABJD_T_25ZR1A4B_M',
#                                                       '2DD8RVP8_T_XHLPBARC_M',
#                                                       '1Y5U23JX_T_TWVZ4283_M',
#                                                       '1SHJ88W1_T_AQ9TJ4W9_M',
#                                                       '2J0D2U4J_T_XJAFP6HU_M',
#                                                       '32EEXL0X_T_1CD4PX1X_M'],
#                                   selected_features=[]),
#                       DiseaseTree(name='Vascular/lymphatic anomalies',
#                                   children=[DiseaseTree(name='Haemangioma',
#                                                         children=[DiseaseTree(name='Congenital '
#                                                                                    'haemangioma',
#                                                                               children=[],
#                                                                               samples=['2FRQ6RW6_T_12QK30T9_M'],
#                                                                               training_samples=['2FRQ6RW6_T_12QK30T9_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[])],
#                                                         samples=[],
#                                                         training_samples=[],
#                                                         validation_samples=[],
#                                                         selected_features=[])],
#                                   samples=[],
#                                   training_samples=[],
#                                   validation_samples=[],
#                                   selected_features=[]),
#                       DiseaseTree(name='Haematological malignancy',
#                                   children=[DiseaseTree(name='Histiocytosis',
#                                                         children=[DiseaseTree(name='Cutaneous '
#                                                                                    'non-LCH '
#                                                                                    '(C '
#                                                                                    'group)',
#                                                                               children=[],
#                                                                               samples=['1AN7YU11_T_1AENQV6K_M',
#                                                                                        '1THYGGY0_T_11ARMY5Z_M'],
#                                                                               training_samples=['1AN7YU11_T_1AENQV6K_M',
#                                                                                                 '1THYGGY0_T_11ARMY5Z_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Langerhans '
#                                                                                    'cell '
#                                                                                    'histiocytosis',
#                                                                               children=[],
#                                                                               samples=['24ZQZHH1_T_8DN7VPF6_M',
#                                                                                        '1BLNZ63A_T_P2BVYH6D_M',
#                                                                                        '5T36WV8U_T_PNJ0TX1V_M'],
#                                                                               training_samples=['24ZQZHH1_T_8DN7VPF6_M',
#                                                                                                 '1BLNZ63A_T_P2BVYH6D_M',
#                                                                                                 '5T36WV8U_T_PNJ0TX1V_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[])],
#                                                         samples=[],
#                                                         training_samples=[],
#                                                         validation_samples=[],
#                                                         selected_features=[]),
#                                             DiseaseTree(name='Myelodysplastic '
#                                                              'syndrome',
#                                                         children=[DiseaseTree(name='Therapy-related '
#                                                                                    'myelodysplastic '
#                                                                                    'syndrome',
#                                                                               children=[],
#                                                                               samples=['14K7H523_T_2VAT1Q1L_M',
#                                                                                        'X29EXYUF_T_1NZ6S3L7_M',
#                                                                                        'X29EXYUF_T_2Y9CKHLE_M',
#                                                                                        '2GWCVXHQ_T_KMT28SML_M',
#                                                                                        '2SDXQALF_T_1JFW6BRJ_M'],
#                                                                               training_samples=['X29EXYUF_T_2Y9CKHLE_M',
#                                                                                                 '2SDXQALF_T_1JFW6BRJ_M',
#                                                                                                 '2GWCVXHQ_T_KMT28SML_M'],
#                                                                               validation_samples=['14K7H523_T_2VAT1Q1L_M',
#                                                                                                   'X29EXYUF_T_1NZ6S3L7_M'],
#                                                                               selected_features=[])],
#                                                         samples=['1YZDMQMS_T_25SVME1F_M',
#                                                                  '1ZTXX1A4_T_1M3LS3QW_M',
#                                                                  '1CSP7ZEC_T_2TWVD7AF_M'],
#                                                         training_samples=['1YZDMQMS_T_25SVME1F_M',
#                                                                           '1ZTXX1A4_T_1M3LS3QW_M',
#                                                                           '1CSP7ZEC_T_2TWVD7AF_M'],
#                                                         validation_samples=[],
#
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#                                                                                 '2QN05MQ8_T_1D4WLT1X_M',
#                                                                                                                         '1ZYJLMUB_T_2151E6Y6_M',
#                                                                                                                         '4B2VTKJ9_T_SRM7HDTK_M',
#                                                                                                                         '2Z5B13N6_T_21QFNCDQ_M',
#                                                                                                                         '1YXV97Y3_T_2FPAQE6B_M'],
#                                                                                                     selected_features=[]),
#                                                                                         DiseaseTree(name='Diffuse '
#                                                                                                          'midline '
#                                                                                                          'glioma, '
#                                                                                                          'H3 '
#                                                                                                          'K27-altered, '
#                                                                                                          'no '
#                                                                                                          'H3 '
#                                                                                                          'K27M '
#                                                                                                          'mutation',
#                                                                                                     children=[],
#                                                                                                     samples=['97FNR4CR_T_VQKW4U1R_M',
#                                                                                                              '2H5UJABP_T_25T05FXR_M',
#                                                                                                              '1BLAB678_T_WFK9XR4V_M',
#                                                                                                              '283H6KFL_T_1BHMZGN9_M',
#                                                                                                              '30EQ7K79_T_2N95KHWA_M',
#                                                                                                              'DBEPWXK6_T_M7YKCNUY_M',
#                                                                                                              'F0AMNR15_T_1Y7Q90H0_M',
#                                                                                                              'ZFPKKQH6_T_2A7U9HK3_M',
#                                                                                                              '2GZTPVS5_T_ZFVA8MDF_M'],
#                                                                                                     training_samples=['DBEPWXK6_T_M7YKCNUY_M',
#                                                                                                                       '97FNR4CR_T_VQKW4U1R_M',
#                                                                                                                       '2GZTPVS5_T_ZFVA8MDF_M',
#                                                                                                                       '1BLAB678_T_WFK9XR4V_M',
#                                                                                                                       '30EQ7K79_T_2N95KHWA_M',
#                                                                                                                       '283H6KFL_T_1BHMZGN9_M',
#                                                                                                                       'F0AMNR15_T_1Y7Q90H0_M'],
#                                                                                                     validation_samples=['ZFPKKQH6_T_2A7U9HK3_M',
#                                                                                                                         '2H5UJABP_T_25T05FXR_M'],
#                                                                                                     selected_features=[])],
#                                                                               samples=[],
#                                                                               training_samples=[],
#                                                                               validation_samples=[],
#                                                                               selected_features=[])],
#                                                         samples=[],
#                                                         training_samples=[],
#                                                         validation_samples=[],
#                                                         selected_features=[]),
#                                             DiseaseTree(name='Glioneuronal and '
#                                                              'neuronal tumour',
#                                                         children=[DiseaseTree(name='Central '
#                                                                                    'neurocytoma',
#                                                                               children=[],
#                                                                               samples=['1UL57VBZ_T_2Y1K6WQA_M'],
#                                                                               training_samples=['1UL57VBZ_T_2Y1K6WQA_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Desmoplastic '
#                                                                                    'infantile '
#                                                                                    'ganglioglioma '
#                                                                                    'and '
#                                                                                    'astrocytoma',
#                                                                               children=[],
#                                                                               samples=['EFSYTMNS_T_1LS0RRH2_M'],
#                                                                               training_samples=['EFSYTMNS_T_1LS0RRH2_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Diffuse '
#                                                                                    'glioneuronal '
#                                                                                    'tumour '
#                                                                                    'with '
#                                                                                    'oligodendroglioma-like '
#                                                                                    'features '
#                                                                                    'and '
#                                                                                    'nuclear '
#                                                                                    'clusters',
#                                                                               children=[],
#                                                                               samples=['1AB4GN6H_T_26SUY5W0_M'],
#                                                                               training_samples=['1AB4GN6H_T_26SUY5W0_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Glioneuronal '
#                                                                                    'tumour, '
#                                                                                    'NOS',
#                                                                               children=[DiseaseTree(name='Glioneuronal '
#                                                                                                          'tumour, '
#                                                                                                          'NOS, '
#                                                                                                          'high '
#                                                                                                          'grade',
#                                                                                                     children=[],
#                                                                                                     samples=['15VQZT7M_T_1T6WDZVC_M',
#                                                                                                              'U75MX3PV_T_UEKWVF8H_M',
#                                                                                                              'PJVD2FJU_T_9E627VL7_M'],
#                                                                                                     training_samples=['15VQZT7M_T_1T6WDZVC_M',
#                                                                                                                       'U75MX3PV_T_UEKWVF8H_M',
#                                                                                                                       'PJVD2FJU_T_9E627VL7_M'],
#                                                                                                     validation_samples=[],
#                                                                                                     selected_features=[]),
#                                                                                         DiseaseTree(name='Glioneuronal '
#                                                                                                          'tumour, '
#                                                                                                          'NOS, '
#                                                                                                          'low '
#                                                                                                          'grade',
#                                                                                                     children=[],
#                                                                                                     samples=['54RU5545_T_99M0STVV_M',
#                                                                                                              '17CWCETR_T_2X5Y1E53_M'],
#                                                                                                     training_samples=['54RU5545_T_99M0STVV_M',
#                                                                                                                       '17CWCETR_T_2X5Y1E53_M'],
#                                                                                                     validation_samples=[],
#                                                                                                     selected_features=[])],
#                                                                               samples=[],
#                                                                               training_samples=[],
#                                                                               validation_samples=[],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Myxoid '
#                                                                                    'glioneuronal '
#                                                                                    'tumour',
#                                                                               children=[],
#                                                                               samples=['MMMPY849_T_2ZNZPT4P_M'],
#                                                                               training_samples=['MMMPY849_T_2ZNZPT4P_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Papillary '
#                                                                                    'glioneuronal '
#                                                                                    'tumour',
#                                                                               children=[],
#                                                                               samples=['27HSW1RN_T_K0H21GHB_M'],
#                                                                               training_samples=['27HSW1RN_T_K0H21GHB_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Diffuse '
#                                                                                    'leptomeningeal '
#                                                                                    'glioneuronal '
#                                                                                    'tumour',
#                                                                               children=[],
#                                                                               samples=['2KP0RV7X_T_LC136AVH_M',
#                                                                                        '6Y14K29V_T_NW33N66R_M',
#                                                                                        '2KP0RV7X_T_YLNVW501_M',
#                                                                                        '1DN1459N_T_2D045L6V_M',
#                                                                                        '25GZG6TX_T_11RFUM89_M'],
#                                                                               training_samples=['25GZG6TX_T_11RFUM89_M',
#                                                                                                 '6Y14K29V_T_NW33N66R_M',
#                                                                                                 '1DN1459N_T_2D045L6V_M',
#                                                                                                 '2KP0RV7X_T_YLNVW501_M'],
#                                                                               validation_samples=['2KP0RV7X_T_LC136AVH_M'],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Rosette-forming '
#                                                                                    'glioneuronal '
#                                                                                    'tumour',
#                                                                               children=[],
#                                                                               samples=['AG4Q2CYW_T_A6HMJAMA_M',
#                                                                                        'RZYHH3V4_T_1BPZXWPA_M',
#                                                                                        '1M42LBH2_T_1E6XCHRN_M',
#                                                                                        '12XMNRUS_T_PNYG2ZFM_M',
#                                                                                        '12XMNRUS_T_Q03VMBDX_M',
#                                                                                        '1J5B1EFX_T_NHDVG7H1_M'],
#                                                                               training_samples=['1J5B1EFX_T_NHDVG7H1_M',
#                                                                                                 '1M42LBH2_T_1E6XCHRN_M',
#                                                                                                 '12XMNRUS_T_Q03VMBDX_M',
#                                                                                                 '12XMNRUS_T_PNYG2ZFM_M'],
#                                                                               validation_samples=['AG4Q2CYW_T_A6HMJAMA_M',
#                                                                                                   'RZYHH3V4_T_1BPZXWPA_M'],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Ganglioglioma',
#                                                                               children=[],
#                                                                               samples=['2XYM5RM3_T_26E6LGZP_M',
#                                                                                        '31EA5J2P_T_19CMNWXR_M',
#                                                                                        'L5AHXJ0X_T_2VPJPE5K_M',
#                                                                                        '2QZTUCUE_T_X8J1B499_M',
#                                                                                        'BTZN8YTZ_T_1AMLVMYQ_M',
#                                                                                        '1BQ5SXLN_T_1CMZQEL5_M',
#                                                                                        '1X4F1UH2_T_21DVN0D3_M',
#                                                                                        '311EF1DK_T_19R1F1H5_M',
#                                                                                        'LED4BT6P_T_2T1ZNF97_M',
#                                                                                        '2R0CFAA0_T_2858WGN1_M',
#                                                                                        '12QJC5BL_T_2VMTF9NX_M',
#                                                                                        '28BLTZFA_T_2G96AW3K_M',
#                                                                                        '1F8KCN9T_T_JM9TJYYR_M'],
#                                                                               training_samples=['28BLTZFA_T_2G96AW3K_M',
#                                                                                                 'BTZN8YTZ_T_1AMLVMYQ_M',
#                                                                                                 '311EF1DK_T_19R1F1H5_M',
#                                                                                                 '31EA5J2P_T_19CMNWXR_M',
#                                                                                                 '2XYM5RM3_T_26E6LGZP_M',
#                                                                                                 '1F8KCN9T_T_JM9TJYYR_M',
#                                                                                                 '2QZTUCUE_T_X8J1B499_M',
#                                                                                                 '1X4F1UH2_T_21DVN0D3_M',
#                                                                                                 '2R0CFAA0_T_2858WGN1_M',
#                                                                                                 'L5AHXJ0X_T_2VPJPE5K_M',
#                                                                                                 '1BQ5SXLN_T_1CMZQEL5_M'],
#                                                                               validation_samples=['LED4BT6P_T_2T1ZNF97_M',
#                                                                                                   '12QJC5BL_T_2VMTF9NX_M'],
#                                                                               selected_features=[]),
#                                                                   DiseaseTree(name='Neuro-epithelial '
#                                                                                    'tumour '
#                                                                                    'with '
#                                                                                    'PATZ1 '
#                                                                                    'fusion',
#                                                                               children=[],
#                                                                               samples=['1B8J69U7_T_3044AKX4_M',
#                                                                                        '1DR6QDQ2_T_16G3NAL1_M',
#                                                                                        '2TD4EHSE_T_2HP9MT2J_M'],
#                                                                               training_samples=['1B8J69U7_T_3044AKX4_M',
#                                                                                                 '1DR6QDQ2_T_16G3NAL1_M',
#                                                                                                 '2TD4EHSE_T_2HP9MT2J_M'],
#                                                                               validation_samples=[],
#                                                                               selected_features=[])],
#                                                         samples=[],
#                                                         training_samples=[],
#                                                         validation_samples=[],
#                                                         selected_features=[])],
#                                   samples=[],
#                                   training_samples=[],
#                                   validation_samples=[],
#                                   selected_features=[]),
#                       DiseaseTree(name='Overgrowth syndrome',
#                                   children=[DiseaseTree(name='Epidermal naevus',
#                                                         children=[],
#                                                         samples=['3Q49KAM9_T_25Q0DGWD_M'],
#                                                         training_samples=['3Q49KAM9_T_25Q0DGWD_M'],
#                                                         validation_samples=[],
#                                                         selected_features=[]),
#                                             DiseaseTree(name='PIK3CA-related '
#                                                              'overgrowth '
#                                                              'tumour',
#                                                         children=[],
#                                                         samples=['16URXX0C_T_1S005XB2_M'],
#                                                         training_samples=['16URXX0C_T_1S005XB2_M'],
#                                                         validation_samples=[],
#                                                         selected_features=[])],
#                                   samples=[],
#                                   training_samples=[],
#                                   validation_samples=[],
#                                   selected_features=[])],
#             samples=[],
#             training_samples=[],
#             validation_samples=[],
#             selected_features=[])
# read Joblib done 117 samples total
# ['1058BL97_T_1W2L50GD_M', '1154A61T_T_240EGBJN_M', '11UWUZG9_T_2J5K19WW_M', '12Y3706V_T_227JABDK_M', '13FGQ1RK_T_31DX5T5P_M', '14TMLV7X_T_LVNKHGVE_M', '16AFE0RY_T_16XF153Q_M', '18XF3EWD_T_2GCRYVSC_M', '1BH0ZUW3_T_28VLPVQ3_M', '1C7CRKRQ_T_1YP0JZ9M_M']
# 🔹 CSV count: 2470
# 🔹 Joblib count: 117
# 🔹 joint count: 110
# 🔹 CSV only: 2360
# 🔹 Joblib only: 7
# Align output: /Workspace/9900-f18a-cake/working_branch/data/freeze0525/biosample_alignment.csv
#         biosample_id_csv  in_joblib
# 0  1VTFN1PB_T_10ABF89W_M      False
# 1  31VV0UE6_T_2T11JBPR_M      False
# 2  QBRTKD9M_T_JC3X7RM2_M      False
# 3  1Z5PB65G_T_BRC2KNQ9_M      False
# 4  AJ8Y0Y11_T_D09FHKFK_M      False
# 5  LRZQW312_T_2CRF4K8R_M      False
# 6  1HHFFJQ3_T_1XKQCCBE_M      False
# 7  YZ9VV29K_T_19DAGHNA_M      False
# 8  1PU5WDA7_T_14DZ1Y0Y_M      False
# 9  29BEVT2D_T_13378YAB_M      False

# %%
from pprint import pprint
import joblib
import polars as pl
import re
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import sys
sys.path.append(r"/Workspace/9900-f18a-cake/working_branch/src")

obj = joblib.load(JOBLIB_PATH)

print(type(obj))
pprint(obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-6021909410971628>, line 11
#       8 import sys
#       9 sys.path.append(r"/Workspace/9900-f18a-cake/working_branch/src")
# ---> 11 obj = joblib.load(JOBLIB_PATH)
#      13 print(type(obj))
#      14 pprint(obj)
#
# NameError: name 'JOBLIB_PATH' is not defined
